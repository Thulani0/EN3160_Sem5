# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the architectural image (base image) and the flag image
base_image = cv2.imread('architectural_image.jpg')
flag_image = cv2.imread('flag_image.png')


# Define four points on the base image (you should adjust these points)
points_base = np.array([[120, 220], [540, 300], [540, 540], [100, 540]], dtype=np.float32)

# Define the corresponding points on the flag image (keep the same order as base points)
points_flag = np.array([[0, 0], [flag_image.shape[1], 0], [flag_image.shape[1], flag_image.shape[0]], [0, flag_image.shape[0]]], dtype=np.float32)

# Calculate the homography matrix
homography_matrix, _ = cv2.findHomography(points_flag, points_base)

# Warp the flag image using the homography matrix
flag_warped = cv2.warpPerspective(flag_image, homography_matrix, (base_image.shape[1], base_image.shape[0]))

# Blend the warped flag image with the base image
result = cv2.addWeighted(base_image, 1, flag_warped, 0.7, 0)

# display the base image with grid on it
plt.figure(figsize=(25, 25))
plt.subplot(1,2,1)
plt.imshow(cv2.cvtColor(base_image, cv2.COLOR_BGR2RGB))
plt.xticks(np.arange(0, base_image.shape[1], 20), fontsize=5)
plt.yticks(np.arange(0, base_image.shape[0], 20))
plt.grid(True, color='white', linewidth=1)
plt.title('Architectural Image')


plt.subplot(1,2,2)
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.title('Superimposed Image')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the architectural image (base image) and the flag image
base_image = cv2.imread('Book.jpg')
cover_image = cv2.imread('snow white.jpg')


# Define four points on the base image (you should adjust these points)
points_base = np.array([[220, 8], [450, 35], [280, 320], [40, 260]], dtype=np.float32)

# Define the corresponding points on the flag image (keep the same order as base points)
points_flag = np.array([[0, 0], [cover_image.shape[1], 0], [cover_image.shape[1], cover_image.shape[0]], [0, cover_image.shape[0]]], dtype=np.float32)

# Calculate the homography matrix
homography_matrix, _ = cv2.findHomography(points_flag, points_base)

# Warp the flag image using the homography matrix
flag_warped = cv2.warpPerspective(cover_image, homography_matrix, (base_image.shape[1], base_image.shape[0]))

# Blend the warped flag image with the base image
result = cv2.addWeighted(base_image, 0.3, flag_warped, 0.9, 0)

# display the base image with grid on it
plt.figure(figsize=(10, 3))
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(base_image, cv2.COLOR_BGR2RGB))
plt.xticks(np.arange(0, base_image.shape[1], 40), fontsize=5)
plt.yticks(np.arange(0, base_image.shape[0], 20))
plt.grid(True, color='red', linewidth=1)
plt.title('Book')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(cover_image, cv2.COLOR_BGR2RGB))
plt.title('Cover Image')



plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.title('Superimposed Image')
plt.show()

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# Load the architectural image (base image) and the flag image
base_image = cv2.imread('Glass door.jpg')
cover_image = cv2.imread('snow_white.webp')


# Define four points on the base image (you should adjust these points)
points_base_L = np.array([[20, 150], [400, 160], [400, 980], [20, 1000]], dtype=np.float32)
points_base_R = np.array([[460, 150], [870, 150], [870, 980], [460, 980]], dtype=np.float32)

# Define the corresponding points on the flag image (keep the same order as base points)
points_flag_L = np.array([[0, 0], [cover_image.shape[1], 0], [cover_image.shape[1], cover_image.shape[0]], [0, cover_image.shape[0]]], dtype=np.float32)
points_flag_R = np.array([[0, 0], [cover_image.shape[1], 0], [cover_image.shape[1], cover_image.shape[0]], [0, cover_image.shape[0]]], dtype=np.float32)

# Calculate the homography matrix
homography_matrix_L, _ = cv2.findHomography(points_flag_L, points_base_L)
homography_matrix_R, _ = cv2.findHomography(points_flag_R, points_base_R)

# Warp the flag image using the homography matrix
flag_warped_L = cv2.warpPerspective(cover_image, homography_matrix_L, (base_image.shape[1], base_image.shape[0]))
flag_warped_R = cv2.warpPerspective(cover_image, homography_matrix_R, (base_image.shape[1], base_image.shape[0]))

# Blend the warped flag image with the base image
result = cv2.addWeighted(base_image, 0.5, flag_warped_L, 0.7, 0)
result = cv2.addWeighted(result, 1, flag_warped_R, 0.7, 0)

# display the base image with grid on it
plt.figure(figsize=(10, 3))
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(base_image, cv2.COLOR_BGR2RGB))
plt.xticks(np.arange(0, base_image.shape[1], 100), fontsize=5)
plt.yticks(np.arange(0, base_image.shape[0], 100))
plt.grid(True, color='red', linewidth=1)
plt.title('Book')

plt.subplot(1,3,2)
plt.imshow(cv2.cvtColor(cover_image, cv2.COLOR_BGR2RGB))
plt.title('Cover Image')



plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(result, cv2.COLOR_BGR2RGB))
plt.title('Superimposed Image')
plt.show()
